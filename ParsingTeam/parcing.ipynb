# %%
import json
import re

# %%
import nltk
def stopWordRemoval( wordList ):
    swords = nltk.corpus.stopwords.words('english')
    return [w for w in wordList if w not in swords ]

# %%
data = []
with open('AI2-8thGr-NDMC-Feb2016-Train.jsonl') as f:
    for line in f:
        question=json.loads(line)
        q_dict={}
        temp_str=question['question']['stem'].encode('utf-8').strip()
        q_dict['Q']=re.sub("[^\w]", " ",  temp_str).split()
        q_dict['Q'] = stopWordRemoval(q_dict['Q'])
        for opt in question['question']['choices']:
            temp_str=opt['text'].encode('utf-8').strip()
            q_dict[opt['label'].encode('utf-8').strip()]=re.sub("[^\w]", " ",  temp_str).split()
        data.append(q_dict)

# %%
data
# Out:
# [{'A': ['atmospheric', 'pressure'],
#   'B': ['gravitational', 'force'],
#   'C': ['electromagnetic', 'energy'],
#   'D': ['thermal', 'energy'],
#   'Q': ['Which',
#    'following',
#    'keeps',
#    'planets',
#    'solar',
#    'system',
#    'orbit',
#    'around',
#    'Sun']},
#  {'A': ['carnivores'],
#   'B': ['decomposers'],
#   'C': ['herbivores'],
#   'D': ['producers'],
#   'Q': ['Which',
#    'following',
#    'groups',
#    'organisms',
#    'uses',
#    'sunlight',
#    'convert',
#    'carbon',
#    'dioxide',
#    'water',
#    'sugar',
#    'oxygen']},
#  {'A': ['glass'],
#   'B': ['metal'],
#   'C': ['paper'],
#   'D': ['plastic'],
#   'Q': ['A',
#    'manufacturer',
#    'wants',
#    'produce',
#    'container',
#    'food',
#    'storage',
#    'break',
#    'easily',
#    'airtight',
#    'inexpensive',
#    'microwave',
#    'safe',
#    'Which',
#    'following',
#    'best',
#    'material',
#    'use',
#    'make',
#    'container']},
#  {'A': ['conduction', 'in', 'the', 'ocean'],
#   'B': ['convection', 'in', 'the', 'mantle'],
#   'C': ['radiation', 'from', 'the', 'solid', 'core'],
#   'D': ['evaporation', 'at', 'mid', 'ocean', 'ridges'],
#   'Q': ['Heat',
#    'deep',
#    'Earth',
#    'interior',
#    'transferred',
#    'crust',
#    'following']},
#  {'A': ['There', 'is', 'a', 'greater', 'number', 'of', 'offspring'],
#   'B': ['There', 'is', 'more', 'food', 'available', 'to', 'offspring'],
#   'C': ['There', 'is', 'greater', 'genetic', 'variety', 'in', 'offspring'],
#   'D': ['There',
#    'is',
#    'a',
#    'longer',
#    'development',
#    'time',
#    'for',
#    'offspring'],
#   'Q': ['Which',
#    'following',
#    'primary',
#    'advantage',
#    'sexual',
#    'reproduction',
#    'compared',
#    'asexual',
#    'reproduction']},
#  {'A': ['The', 'equator', 'is', 'closer', 'to', 'the', 'Sun'],
#   'B': ['The', 'equator', 'has', 'higher', 'sea', 'levels'],
#   'C': ['The', 'equator', 'receives', 'more', 'direct', 'sunlight'],
#   'D': ['The',
#    'equator',
#    'rotates',
#    'more',
#    'quickly',
#    'on',
#    'Earth',
#    's',
#    'axis'],
#   'Q': ['The',
#    'ocean',
#    'water',
#    'near',
#    'equator',
#    'absorbs',
#    'heat',
#    'throughout',
#    'year',
#    'ocean',
#    'water',
#    'near',
#    'North',
#    'Pole',
#    'Which',
#    'following',
#    'best',
#    'explains',
#    'difference']},
#  {'A': ['A',
#    'log',
#    'gives',
#    'off',
#    'heat',
#    'and',
#    'light',
#    'as',
#    'it',
#    'burns'],
#   'B': ['A',
#    'tree',
#    'stores',
#    'energy',
#    'from',
#    'the',
#    'Sun',
#    'in',
#    'its',
#    'fruit'],
#   'C': ['A',
#    'penny',
#    'lost',
#    'in',
#    'the',
#    'grass',
#    'slowly',
#    'changes',
#    'color'],
#   'D': ['A',
#    'water',
#    'pipe',
#    'freezes',
#    'and',
#    'cracks',
#    'on',
#    'a',
#    'cold',
#    'night'],
#   'Q': ['Which',
#    'following',
#    'example',
#    'physical',
#    'change',
#    'chemical',
#    'change']},
#  {'A': ['crust'],
#   'B': ['mantle'],
#   'C': ['inner', 'core'],
#   'D': ['outer', 'core'],
#   'Q': ['Which', 'following', 'Earth', 'layers', 'greatest', 'density']},
#  {'A': ['rust', 'forming', 'on', 'an', 'iron', 'nail'],
#   'B': ['sugar', 'crystals', 'dissolving', 'in', 'water'],
#   'C': ['sodium', 'and', 'chlorine', 'forming', 'table', 'salt'],
#   'D': ['hydrogen', 'and', 'oxygen', 'reacting', 'to', 'produce', 'water'],
#   'Q': ['Which', 'following', 'example', 'formation', 'mixture']},
#  {'A': ['decoder'],
#   'B': ['encoder'],
#   'C': ['receiver'],
#   'D': ['transmitter'],
#   'Q': ['Which',
#    'following',
#    'identifies',
#    'primary',
#    'function',
#    'radio',
#    'station',
#    'tower',
#    'communication',
#    'system']},
#  {'A': ['0', 'C'],
#   'B': ['15', 'C'],
#   'C': ['37', 'C'],
#   'D': ['50', 'C'],
#   'Q': ['Laura',
#    'adds',
#    '50',
#    'mL',
#    'boiling',
#    'water',
#    '100',
#    'mL',
#    'ice',
#    'water',
#    'If',
#    '150',
#    'mL',
#    'water',
#    'put',
#    'freezer',
#    'temperature',
#    'water',
#    'freeze']},
#  {'A': ['nitrogen'],
#   'B': ['zinc'],
#   'C': ['air'],
#   'D': ['aluminum'],
#   'Q': ['Which',
#    'following',
#    'substances',
#    'separated',
#    'several',
#    'elements']},
#  {'A': ['distribution'],
#   'B': ['mass', 'marketing'],
#   'C': ['public', 'relations'],
#   'D': ['research'],
#   'Q': ['Scientists',
#    'working',
#    'company',
#    'testing',
#    'new',
#    'medicine',
#    'think',
#    'help',
#    'heal',
#    'damaged',
#    'tissue',
#    'In',
#    'part',
#    'company',
#    'scientists',
#    'working']},
#  {'A': ['The',
#    'rock',
#    'found',
#    'in',
#    'California',
#    'is',
#    'igneous',
#    'but',
#    'the',
#    'rock',
#    'found',
#    'in',
#    'Massachusetts',
#    'is',
#    'sedimentary'],
#   'B': ['California',
#    'is',
#    'located',
#    'on',
#    'the',
#    'boundary',
#    'of',
#    'two',
#    'crustal',
#    'plates',
#    'but',
#    'Massachusetts',
#    'is',
#    'not'],
#   'C': ['The',
#    'rock',
#    'under',
#    'California',
#    'is',
#    'soft',
#    'but',
#    'the',
#    'rock',
#    'under',
#    'Massachusetts',
#    'is',
#    'hard'],
#   'D': ['California',
#    'is',
#    'located',
#    'on',
#    'a',
#    'continental',
#    'plate',
#    'but',
#    'Massachusetts',
#    'is',
#    'not'],
#   'Q': ['Which',
#    'following',
#    'statements',
#    'best',
#    'explains',
#    'earthquakes',
#    'occur',
#    'frequently',
#    'California',
#    'Massachusetts']},
#  {'A': ['5', 's'],
#   'B': ['10', 's'],
#   'C': ['15', 's'],
#   'D': ['20', 's'],
#   'Q': ['An',
#    'escalator',
#    'shopping',
#    'mall',
#    '10',
#    'long',
#    'moves',
#    'constant',
#    'speed',
#    '0',
#    '5',
#    'If',
#    'Jos',
#    'steps',
#    'onto',
#    'escalator',
#    'bottom',
#    'moving',
#    'long',
#    'take',
#    'travel',
#    '10']},
#  {'A': ['a', 'sea', 'floor'],
#   'B': ['a', 'windblown', 'desert'],
#   'C': ['a', 'site', 'deep', 'underground'],
#   'D': ['a', 'site', 'covered', 'by', 'a', 'glacier'],
#   'Q': ['Which',
#    'following',
#    'areas',
#    'likely',
#    'form',
#    'metamorphic',
#    'rocks',
#    'gneiss',
#    'schist']},
#  {'A': ['Interchangeable',
#    'parts',
#    'are',
#    'generally',
#    'more',
#    'expensive',
#    'than',
#    'custom',
#    'made',
#    'parts',
#    'for',
#    'automobiles'],
#   'B': ['Interchangeable',
#    'parts',
#    'break',
#    'more',
#    'often',
#    'now',
#    'than',
#    'in',
#    'years',
#    'past',
#    'on',
#    'most',
#    'automobiles'],
#   'C': ['Interchangeable',
#    'parts',
#    'are',
#    'plentiful',
#    'for',
#    'custom',
#    'made',
#    'automobiles'],
#   'D': ['Interchangeable',
#    'parts',
#    'can',
#    'fit',
#    'many',
#    'kinds',
#    'of',
#    'automobiles'],
#   'Q': ['Several',
#    'interchangeable',
#    'parts',
#    'used',
#    'manufacture',
#    'automobiles',
#    'Some',
#    'examples',
#    'parts',
#    'batteries',
#    'windshield',
#    'wiper',
#    'blades',
#    'spark',
#    'plugs',
#    'tires',
#    'Which',
#    'following',
#    'advantage',
#    'interchangeable',
#    'parts',
#    'non',
#    'interchangeable',
#    'parts',
#    'automobiles']},
#  {'A': ['23', 'pairs', 'of', 'chromosomes'],
#   'B': ['46', 'different', 'types', 'of', 'chromosomes'],
#   'C': ['46', 'male', 'chromosomes', 'and', '46', 'female', 'chromosomes'],
#   'D': ['23',
#    'original',
#    'chromosomes',
#    'and',
#    '23',
#    'duplicate',
#    'chromosomes'],
#   'Q': ['Which',
#    'following',
#    'best',
#    'describes',
#    'number',
#    'chromosomes',
#    'normal',
#    'human',
#    'liver',
#    'cell']},
#  {'A': ['capturing', 'energy', 'from', 'sunlight'],
#   'B': ['consuming', 'living', 'plant', 'material'],
#   'C': ['taking', 'energy', 'from', 'animal', 'hosts'],
#   'D': ['breaking', 'down', 'dead', 'plant', 'material'],
#   'Q': ['Which',
#    'following',
#    'best',
#    'describes',
#    'role',
#    'mushrooms',
#    'ecosystems']},
#  {'A': ['chisel'],
#   'B': ['pliers'],
#   'C': ['sander'],
#   'D': ['saw'],
#   'Q': ['Which',
#    'following',
#    'tools',
#    'useful',
#    'tightening',
#    'small',
#    'mechanical',
#    'fastener']},
#  {'A': ['A', 'different', 'state', 'of', 'matter', 'is', 'produced'],
#   'B': ['Some', 'mass', 'is', 'converted', 'to', 'energy'],
#   'C': ['Some', 'form', 'of', 'light', 'is', 'given', 'off'],
#   'D': ['A', 'new', 'material', 'is', 'formed'],
#   'Q': ['Which', 'following', 'characteristic', 'chemical', 'changes']},
#  {'A': ['digestive'],
#   'B': ['immune'],
#   'C': ['nervous'],
#   'D': ['respiratory'],
#   'Q': ['In',
#    'human',
#    'body',
#    'system',
#    'functions',
#    'primarily',
#    'defend',
#    'body',
#    'disease']},
#  {'A': ['an', 'atom'],
#   'B': ['a', 'compound'],
#   'C': ['an', 'electron'],
#   'D': ['a', 'molecule'],
#   'Q': ['What',
#    'smallest',
#    'unit',
#    'element',
#    'still',
#    'properties',
#    'element']},
#  {'A': ['carbon', 'dioxide'],
#   'B': ['food'],
#   'C': ['protection'],
#   'D': ['water'],
#   'Q': ['Lichens',
#    'symbiotic',
#    'organisms',
#    'made',
#    'green',
#    'algae',
#    'fungi',
#    'What',
#    'green',
#    'algae',
#    'supply',
#    'fungi',
#    'symbiotic',
#    'relationship']},
#  {'A': ['Customers',
#    'can',
#    'provide',
#    'specific',
#    'feedback',
#    'to',
#    'workers'],
#   'B': ['Workers',
#    'become',
#    'skilled',
#    'in',
#    'all',
#    'aspects',
#    'of',
#    'assembly'],
#   'C': ['Goods', 'can', 'be', 'easily', 'modified', 'for', 'customers'],
#   'D': ['Products', 'can', 'be', 'made', 'at', 'a', 'lower', 'cost'],
#   'Q': ['Which',
#    'following',
#    'best',
#    'describes',
#    'advantage',
#    'using',
#    'mass',
#    'production',
#    'manufacturing',
#    'system',
#    'instead',
#    'custom',
#    'manufacturing',
#    'system']},
#  {'A': ['to',
#    'improve',
#    'the',
#    'flavors',
#    'by',
#    'increasing',
#    'the',
#    'sugar',
#    'content'],
#   'B': ['to',
#    'speed',
#    'up',
#    'the',
#    'ripening',
#    'of',
#    'produce',
#    'picked',
#    'too',
#    'early'],
#   'C': ['to',
#    'partially',
#    'cook',
#    'the',
#    'produce',
#    'before',
#    'canning',
#    'or',
#    'freezing'],
#   'D': ['to',
#    'extend',
#    'the',
#    'shelf',
#    'life',
#    'by',
#    'killing',
#    'existing',
#    'microorganisms'],
#   'Q': ['Which',
#    'following',
#    'describes',
#    'reason',
#    'companies',
#    'irradiate',
#    'fruits',
#    'vegetables',
#    'sold',
#    'public']},
#  {'A': ['chemical', 'forces'],
#   'B': ['gravity'],
#   'C': ['magnetism'],
#   'D': ['nuclear', 'forces'],
#   'Q': ['Which',
#    'following',
#    'causes',
#    'ship',
#    'iron',
#    'anchor',
#    'sink',
#    'ocean',
#    'floor',
#    'released',
#    'overboard']},
#  {'A': ['chisel'],
#   'B': ['pliers'],
#   'C': ['saw'],
#   'D': ['sander'],
#   'Q': ['Which',
#    'following',
#    'tools',
#    'useful',
#    'tightening',
#    'small',
#    'mechanical',
#    'fastener']},
#  {'A': ['tens'],
#   'B': ['hundreds'],
#   'C': ['thousands'],
#   'D': ['billions'],
#   'Q': ['Which',
#    'following',
#    'best',
#    'estimate',
#    'number',
#    'stars',
#    'typical',
#    'galaxy']},
#  {'A': ['the', 'color', 'of', 'the', 'organism'],
#   'B': ['the', 'organism', 's', 'natural', 'habitat'],
#   'C': ['the', 'structure', 'of', 'the', 'organism', 's', 'anatomy'],
#   'D': ['the', 'location', 'where', 'the', 'organism', 'was', 'found'],
#   'Q': ['If',
#    'new',
#    'organism',
#    'discovered',
#    'following',
#    'would',
#    'likely',
#    'used',
#    'classify',
#    'appropriate',
#    'kingdom']},
#  {'A': ['an', 'atom'],
#   'B': ['a', 'compound'],
#   'C': ['an', 'electron'],
#   'D': ['a', 'mixture'],
#   'Q': ['Which',
#    'following',
#    'formed',
#    'two',
#    'elements',
#    'combine',
#    'chemically']},
#  {'A': ['designing', 'a', 'process'],
#   'B': ['generating', 'output'],
#   'C': ['giving', 'feedback'],
#   'D': ['setting', 'a', 'goal'],
#   'Q': ['After',
#    'windstorm',
#    'Niko',
#    'called',
#    'electric',
#    'company',
#    'report',
#    'electricity',
#    'His',
#    'phone',
#    'call',
#    'example',
#    'following',
#    'elements',
#    'universal',
#    'systems',
#    'model']},
#  {'A': ['The',
#    'warm',
#    'ocean',
#    'currents',
#    'flow',
#    'from',
#    'the',
#    'tropics',
#    'to',
#    'the',
#    'Northern',
#    'Hemisphere',
#    'in',
#    'the',
#    'summer'],
#   'B': ['The',
#    'rays',
#    'of',
#    'the',
#    'Sun',
#    'strike',
#    'the',
#    'Northern',
#    'Hemisphere',
#    'more',
#    'directly',
#    'in',
#    'the',
#    'summer'],
#   'C': ['The',
#    'greenhouse',
#    'effect',
#    'increases',
#    'in',
#    'the',
#    'Northern',
#    'Hemisphere',
#    'in',
#    'the',
#    'summer'],
#   'D': ['The',
#    'Northern',
#    'Hemisphere',
#    'is',
#    'closer',
#    'to',
#    'the',
#    'Sun',
#    'in',
#    'the',
#    'summer'],
#   'Q': ['Which',
#    'following',
#    'statements',
#    'best',
#    'explains',
#    'tilt',
#    'Earth',
#    'axis',
#    'causes',
#    'summer',
#    'warmer',
#    'winter',
#    'Northern',
#    'Hemisphere']},
#  {'A': ['crustal', 'deformation'],
#   'B': ['frequent', 'earthquakes'],
#   'C': ['glacial', 'movement'],
#   'D': ['volcanic', 'eruptions'],
#   'Q': ['When',
#    'bedrock',
#    'Massachusetts',
#    'examined',
#    'often',
#    'appears',
#    'scraped',
#    'polished',
#    'Which',
#    'following',
#    'likely',
#    'caused',
#    'bedrock',
#    'appear',
#    'scraped',
#    'polished']},
#  {'A': ['50', 'g'],
#   'B': ['75', 'g'],
#   'C': ['100', 'g'],
#   'D': ['125', 'g'],
#   'Q': ['Ms',
#    'Bristol',
#    'measured',
#    'mass',
#    'closed',
#    'beaker',
#    'containing',
#    'several',
#    'ice',
#    'cubes',
#    'The',
#    'mass',
#    '100',
#    'g',
#    'An',
#    'hour',
#    'later',
#    'ice',
#    'cubes',
#    'melted',
#    'Ms',
#    'Bristol',
#    'measured',
#    'mass',
#    'beaker',
#    'What',
#    'mass',
#    'beaker',
#    'water',
#    'second',
#    'time']},
#  {'A': ['construct',
#    'prototypes',
#    'of',
#    'different',
#    'kinds',
#    'of',
#    'bridges'],
#   'B': ['research', 'the', 'different', 'designs', 'of', 'bridges'],
#   'C': ['gather',
#    'the',
#    'materials',
#    'needed',
#    'to',
#    'build',
#    'the',
#    'bridge'],
#   'D': ['make',
#    'a',
#    'drawing',
#    'to',
#    'show',
#    'how',
#    'to',
#    'build',
#    'the',
#    'bridge'],
#   'Q': ['For',
#    'technology',
#    'project',
#    'Kyle',
#    'came',
#    'idea',
#    'build',
#    'model',
#    'bridge',
#    'He',
#    'wants',
#    'bridge',
#    'span',
#    '50',
#    'cm',
#    'support',
#    '1',
#    'kg',
#    'object',
#    'According',
#    'engineering',
#    'design',
#    'process',
#    'following',
#    'Kyle',
#    'next',
#    'step']},
#  {'A': ['the', 'spread', 'of', 'disease'],
#   'B': ['the', 'availability', 'of', 'water'],
#   'C': ['the', 'recycling', 'of', 'nutrients'],
#   'D': ['the', 'distribution', 'of', 'organisms'],
#   'Q': ['The',
#    'complete',
#    'removal',
#    'decomposers',
#    'ecosystem',
#    'greatest',
#    'effect',
#    'following']},
#  {'A': ['millimeters'],
#   'B': ['centimeters'],
#   'C': ['meters'],
#   'D': ['kilometers'],
#   'Q': ['New',
#    'carpet',
#    'measured',
#    'room',
#    '5',
#    '5',
#    '4',
#    '6',
#    'On',
#    'measuring',
#    'tape',
#    'smallest',
#    'unit',
#    'necessary',
#    'measure',
#    'room',
#    'accurately',
#    'carpet']},
#  {'A': ['The', 'Moon', 'is', 'not', 'solid'],
#   'B': ['The', 'Moon', 'has', 'no', 'gravity'],
#   'C': ['The', 'Moon', 'has', 'almost', 'no', 'atmosphere'],
#   'D': ['The', 'Moon', 'receives', 'almost', 'no', 'solar', 'light'],
#   'Q': ['Which',
#    'following',
#    'statements',
#    'best',
#    'describes',
#    'one',
#    'way',
#    'Moon',
#    'different',
#    'Earth']},
#  {'A': ['quality', 'control'],
#   'B': ['product', 'distribution'],
#   'C': ['production', 'selection'],
#   'D': ['research', 'and', 'development'],
#   'Q': ['A',
#    'shoe',
#    'manufacturer',
#    'randomly',
#    'selects',
#    '10',
#    'production',
#    'shift',
#    'Each',
#    'shoes',
#    'checked',
#    'ensure',
#    'correctly',
#    'made',
#    'What',
#    'process',
#    'called']},
#  {'A': ['10', 'km', 'hr'],
#   'B': ['15', 'km', 'hr'],
#   'C': ['20', 'km', 'hr'],
#   'D': ['25', 'km', 'hr'],
#   'Q': ['Tobias',
#    'rode',
#    'bike',
#    'road',
#    '2',
#    'hr',
#    'period',
#    'On',
#    'average',
#    'passed',
#    '1',
#    'km',
#    'marker',
#    'every',
#    '3',
#    'min',
#    'period',
#    'Which',
#    'following',
#    'average',
#    'speed',
#    '2',
#    'hr',
#    'period']},
#  {'A': ['worm'],
#   'B': ['rabbit'],
#   'C': ['hawk'],
#   'D': ['grass'],
#   'Q': ['Which', 'following', 'organisms', 'produces', 'energy', 'sunlight']},
#  {'A': ['an', 'atom'],
#   'B': ['a', 'compound'],
#   'C': ['an', 'electron'],
#   'D': ['a', 'mixture'],
#   'Q': ['Sugar',
#    'composed',
#    'carbon',
#    'hydrogen',
#    'oxygen',
#    'Sugar',
#    'example',
#    'following']},
#  {'A': ['Both',
#    'the',
#    'water',
#    'and',
#    'metal',
#    'will',
#    'adjust',
#    'to',
#    'the',
#    'same',
#    'temperature',
#    'below',
#    '10',
#    'C'],
#   'B': ['The',
#    'water',
#    'and',
#    'metal',
#    'will',
#    'adjust',
#    'to',
#    'different',
#    'temperatures',
#    'above',
#    '120',
#    'C'],
#   'C': ['The',
#    'water',
#    'will',
#    'remain',
#    'the',
#    'same',
#    'temperature',
#    'but',
#    'the',
#    'metal',
#    'will',
#    'cool',
#    'to',
#    '10',
#    'C'],
#   'D': ['The',
#    'water',
#    'and',
#    'metal',
#    'will',
#    'adjust',
#    'to',
#    'the',
#    'same',
#    'temperature',
#    'between',
#    '10',
#    'C',
#    'and',
#    '120',
#    'C'],
#   'Q': ['The',
#    'surface',
#    'heated',
#    'metal',
#    'object',
#    'measures',
#    '120',
#    'C',
#    'It',
#    'dropped',
#    'bucket',
#    'filled',
#    'water',
#    'measuring',
#    '10',
#    'C',
#    'Which',
#    'following',
#    'likely',
#    'occur']},
#  {'A': ['wide', 'riverbeds'],
#   'B': ['U', 'shaped', 'valleys'],
#   'C': ['underground', 'caves'],
#   'D': ['groundwater', 'springs'],
#   'Q': ['The',
#    'presence',
#    'following',
#    'geological',
#    'features',
#    'provides',
#    'best',
#    'evidence',
#    'glaciers',
#    'covered',
#    'area']},
#  {'A': ['to',
#    'store',
#    'the',
#    'genetic',
#    'instructions',
#    'needed',
#    'to',
#    'specify',
#    'traits'],
#   'B': ['to',
#    'release',
#    'energy',
#    'by',
#    'breaking',
#    'down',
#    'food',
#    'molecules'],
#   'C': ['to',
#    'transport',
#    'nutrients',
#    'into',
#    'and',
#    'out',
#    'of',
#    'the',
#    'cell'],
#   'D': ['to', 'protect', 'the', 'cells', 'from', 'microorganisms'],
#   'Q': ['Which',
#    'following',
#    'best',
#    'describes',
#    'purpose',
#    'chromosomes',
#    'nucleus',
#    'cell']},
#  {'A': ['The', 'hot', 'stove', 'absorbed', 'cold', 'from', 'the', 'pot'],
#   'B': ['The', 'cold', 'water', 'absorbed', 'heat', 'from', 'the', 'pot'],
#   'C': ['The',
#    'hot',
#    'stove',
#    'gave',
#    'off',
#    'heat',
#    'to',
#    'the',
#    'surrounding',
#    'air'],
#   'D': ['The',
#    'cold',
#    'water',
#    'gave',
#    'off',
#    'cold',
#    'to',
#    'the',
#    'surrounding',
#    'air'],
#   'Q': ['A',
#    'pot',
#    'cold',
#    'water',
#    'heated',
#    'stove',
#    'water',
#    'boiled',
#    'Which',
#    'following',
#    'best',
#    'explains',
#    'water',
#    'able',
#    'boil']},
#  {'A': ['core'],
#   'B': ['sediment'],
#   'C': ['lithosphere'],
#   'D': ['hemisphere'],
#   'Q': ['A',
#    'layer',
#    'solid',
#    'brittle',
#    'rock',
#    'comprises',
#    'outer',
#    '100',
#    'kilometers',
#    'Earth',
#    'This',
#    'layer',
#    'contains',
#    'crust',
#    'upper',
#    'mantle',
#    'called']},
#  {'A': ['cell', 'membrane'],
#   'B': ['cell', 'wall'],
#   'C': ['mitochondrion'],
#   'D': ['nucleus'],
#   'Q': ['Which', 'following', 'structures', 'present', 'animal', 'cells']},
#  {'A': ['the', 'Sun'],
#   'B': ['the', 'Moon'],
#   'C': ['Earth', 's', 'gravity'],
#   'D': ['Earth', 's', 'rotation'],
#   'Q': ['What',
#    'primary',
#    'energy',
#    'source',
#    'drives',
#    'weather',
#    'events',
#    'including',
#    'precipitation',
#    'hurricanes',
#    'tornados']},
#  {'A': ['Limiting', 'the', 'number', 'of', 'cars', 'on', 'the', 'roads'],
#   'B': ['Switching', 'to', 'wood', 'stoves', 'for', 'home', 'heating'],
#   'C': ['Requiring', 'large', 'vehicles', 'to', 'use', 'diesel', 'fuel'],
#   'D': ['Maintaining', 'filters', 'in', 'large', 'buildings'],
#   'Q': ['Which',
#    'would',
#    'likely',
#    'improve',
#    'air',
#    'quality',
#    'large',
#    'Texas',
#    'cities']},
#  {'A': ['increasing', 'the', 'pressure', 'inside', 'the', 'wings'],
#   'B': ['decreasing', 'the', 'density', 'of', 'the', 'wings'],
#   'C': ['increasing', 'the', 'temperature', 'inside', 'the', 'wings'],
#   'D': ['decreasing', 'the', 'mass', 'of', 'the', 'wings'],
#   'Q': ['When',
#    'butterfly',
#    'emerges',
#    'chrysalis',
#    'wings',
#    'crumpled',
#    'In',
#    'order',
#    'expand',
#    'wings',
#    'butterfly',
#    'hangs',
#    'upside',
#    'causing',
#    'fluid',
#    'pumped',
#    'veins',
#    'wings',
#    'This',
#    'pumping',
#    'likely',
#    'expands',
#    'wings']},
#  {'A': ['Evaporation'],
#   'B': ['Photosynthesis'],
#   'C': ['Respiration'],
#   'D': ['Decomposition'],
#   'Q': ['Which',
#    'process',
#    'uses',
#    'carbon',
#    'dioxide',
#    'sun',
#    'radiant',
#    'energy',
#    'produce',
#    'chemical',
#    'energy']},
#  {'A': ['Urban', 'development', 'near', 'the', 'coast'],
#   'B': ['Commercial', 'harvesting', 'from', 'the', 'ocean'],
#   'C': ['Climate', 'change', 'on', 'Earth'],
#   'D': ['Acid', 'precipitation', 'over', 'the', 'oceans'],
#   'Q': ['A',
#    'recent',
#    'study',
#    'concluded',
#    '90',
#    'large',
#    'predatory',
#    'fish',
#    'tuna',
#    'disappeared',
#    'world',
#    'oceans',
#    'past',
#    '50',
#    'years',
#    'Which',
#    'likely',
#    'direct',
#    'cause',
#    'loss']},
#  {'A': ['Nutrients',
#    'are',
#    'released',
#    'when',
#    'wood',
#    'is',
#    'broken',
#    'down'],
#   'B': ['Worms', 'produce', 'oxygen', 'used', 'by', 'other', 'organisms'],
#   'C': ['Dead',
#    'trees',
#    'provide',
#    'nest',
#    'sites',
#    'for',
#    'many',
#    'different',
#    'species',
#    'of',
#    'birds'],
#   'D': ['Water', 'is', 'stored', 'in', 'dead', 'trees', 'and', 'limbs'],
#   'Q': ['In',
#    'healthy',
#    'forest',
#    'dead',
#    'trees',
#    'limbs',
#    'fall',
#    'ground',
#    'decompose',
#    'Which',
#    'statements',
#    'best',
#    'describes',
#    'decomposition',
#    'important',
#    'forest',
#    'ecosystem']},
#  {'A': ['has',
#    'a',
#    'higher',
#    'specific',
#    'heat',
#    'than',
#    'the',
#    'metal',
#    'cup'],
#   'B': ['is',
#    'a',
#    'better',
#    'conductor',
#    'of',
#    'heat',
#    'than',
#    'the',
#    'metal',
#    'cup'],
#   'C': ['has',
#    'a',
#    'specific',
#    'heat',
#    'that',
#    'is',
#    'similar',
#    'to',
#    'that',
#    'of',
#    'the',
#    'metal',
#    'cup'],
#   'Q': ['Two',
#    'students',
#    'make',
#    'hot',
#    'chocolate',
#    'One',
#    'student',
#    'pours',
#    'hot',
#    'chocolate',
#    'foam',
#    'cup',
#    'The',
#    'student',
#    'pours',
#    'hot',
#    'chocolate',
#    'metal',
#    'cup',
#    'The',
#    'metal',
#    'cup',
#    'becomes',
#    'hot',
#    'touch',
#    'foam',
#    'cup',
#    'held',
#    'comfortably',
#    'The',
#    'best',
#    'explanation',
#    'difference',
#    'temperature',
#    'foam',
#    'cup',
#    'A',
#    'heats',
#    'much',
#    'faster',
#    'metal',
#    'cup']},
#  {'A': ['Cave'],
#   'B': ['Mountain'],
#   'C': ['Delta'],
#   'D': ['Valley'],
#   'Q': ['As',
#    'river',
#    'enters',
#    'larger',
#    'body',
#    'water',
#    'sediments',
#    'deposited',
#    'wide',
#    'area',
#    'Which',
#    'landforms',
#    'likely',
#    'formed',
#    'site',
#    'deposition']},
#  {'A': ['models'],
#   'B': ['experiments'],
#   'C': ['variables'],
#   'D': ['controls'],
#   'Q': ['The',
#    'items',
#    'listed',
#    'found',
#    'science',
#    'classroom',
#    'heart',
#    'made',
#    'plastic',
#    'many',
#    'parts',
#    'labeled',
#    'clay',
#    'formed',
#    'look',
#    'like',
#    'Earth',
#    'planets',
#    'giant',
#    'plastic',
#    'plant',
#    'cell',
#    'removable',
#    'cell',
#    'parts',
#    'These',
#    'items',
#    'examples']},
#  {'A': ['secrete', 'enzymes'],
#   'B': ['digest', 'proteins'],
#   'C': ['produce', 'hormones'],
#   'D': ['transport', 'materials'],
#   'Q': ['What', 'main', 'function', 'circulatory', 'system']},
#  {'A': ['allergies'],
#   'B': ['vitamin', 'deficiencies'],
#   'C': ['chemical', 'spills'],
#   'D': ['microorganisms'],
#   'Q': ['Infectious', 'diseases', 'caused']},
#  {'A': ['adapt', 'to', 'its', 'environment'],
#   'B': ['become', 'immune', 'to', 'disease'],
#   'C': ['become', 'extinct'],
#   'D': ['increase', 'its', 'population'],
#   'Q': ['If', 'species', 'longer', 'able', 'reproduce']},
#  {'A': ['AIDS'],
#   'B': ['cancer'],
#   'C': ['chicken', 'pox'],
#   'D': ['common', 'cold'],
#   'Q': ['Which', 'disease', 'result', 'abnormal', 'cell', 'division']},
#  {'A': ['stimulus'],
#   'B': ['habit'],
#   'C': ['reflex'],
#   'D': ['source'],
#   'Q': ['A', 'change', 'environment', 'causes', 'response', 'known']},
#  {'A': ['watts'],
#   'B': ['Calories'],
#   'C': ['degrees'],
#   'D': ['pounds'],
#   'Q': ['The', 'energy', 'obtained', 'food', 'measured', 'units', 'called']},
#  {'A': ['reproduce', 'faster'],
#   'B': ['begin', 'to', 'produce', 'their', 'own', 'food'],
#   'C': ['decrease', 'in', 'number'],
#   'D': ['increase', 'in', 'number'],
#   'Q': ['As',
#    'population',
#    'small',
#    'fish',
#    'lake',
#    'decreases',
#    'population',
#    'large',
#    'fish',
#    'depend',
#    'small',
#    'fish',
#    'food']},
#  {'A': ['animal',
#    'growth',
#    'is',
#    'affected',
#    'by',
#    'environmental',
#    'conditions'],
#   'B': ['animal', 'behavior', 'may', 'affect', 'the', 'environment'],
#   'C': ['an', 'animal', 's', 'health', 'depends', 'on', 'its', 'environment'],
#   'D': ['an',
#    'animal',
#    's',
#    'development',
#    'depends',
#    'on',
#    'its',
#    'environment'],
#   'Q': ['Beaver', 'dams', 'cause', 'floods', 'This', 'statement', 'shows']},
#  {'A': ['closed', 'loop', 'system'],
#   'B': ['Punnett', 'square'],
#   'C': ['Periodic', 'Table'],
#   'D': ['water', 'cycle', 'chart'],
#   'Q': ['Which',
#    'scientific',
#    'model',
#    'could',
#    'used',
#    'predict',
#    'properties',
#    'element']},
#  {'A': ['breaks', 'easily', 'when', 'struck', 'with', 'a', 'hammer'],
#   'B': ['bubbles', 'when', 'acid', 'is', 'placed', 'on', 'it'],
#   'C': ['is', 'easily', 'scratched', 'by', 'a', 'fingernail'],
#   'D': ['reflects', 'light', 'from', 'its', 'surface'],
#   'Q': ['A', 'chemical', 'property', 'mineral', 'evident', 'mineral']},
#  {'A': ['lowering', 'parking', 'fees'],
#   'B': ['building', 'larger', 'parking', 'lots'],
#   'C': ['decreasing', 'the', 'cost', 'of', 'gasoline'],
#   'D': ['lowering', 'the', 'cost', 'of', 'bus', 'and', 'subway', 'fares'],
#   'Q': ['City', 'administrators', 'encourage', 'energy', 'conservation']},
#  {'A': ['time', 'and', 'temperature'],
#   'B': ['shape', 'and', 'orbital', 'speed'],
#   'C': ['color', 'and', 'hardness'],
#   'D': ['mass', 'and', 'distance', 'apart'],
#   'Q': ['Which',
#    'two',
#    'factors',
#    'determine',
#    'gravitational',
#    'attraction',
#    'two',
#    'objects']},
#  {'A': ['The', 'Sun', 'and', 'the', 'Moon', 'have', 'the', 'same', 'diameter'],
#   'B': ['The',
#    'Moon',
#    'is',
#    'larger',
#    'in',
#    'diameter',
#    'and',
#    'farther',
#    'from',
#    'Earth',
#    'than',
#    'the',
#    'Sun'],
#   'C': ['The',
#    'Moon',
#    'is',
#    'smaller',
#    'in',
#    'diameter',
#    'and',
#    'is',
#    'closer',
#    'to',
#    'Earth',
#    'than',
#    'the',
#    'Sun'],
#   'D': ['The',
#    'Sun',
#    'and',
#    'the',
#    'Moon',
#    'are',
#    'the',
#    'same',
#    'distance',
#    'from',
#    'Earth'],
#   'Q': ['Which',
#    'statement',
#    'best',
#    'explains',
#    'Sun',
#    'Moon',
#    'appear',
#    'size',
#    'sky']},
#  {'A': ['tidal', 'activity'],
#   'B': ['orbital', 'shape'],
#   'C': ['weather', 'and', 'climate'],
#   'D': ['rotation', 'and', 'revolution'],
#   'Q': ['Dust',
#    'ash',
#    'entering',
#    'atmosphere',
#    'result',
#    'volcanic',
#    'eruptions',
#    'affect',
#    'Earth']},
#  {'A': ['crust'],
#   'B': ['mantle'],
#   'C': ['hydrosphere'],
#   'D': ['atmosphere'],
#   'Q': ['The',
#    'surface',
#    'Earth',
#    'covered',
#    'relatively',
#    'thin',
#    'layer',
#    'water',
#    'called']},
#  {'A': ['fronts'],
#   'B': ['tides'],
#   'C': ['hurricanes'],
#   'D': ['earthquakes'],
#   'Q': ['Movement',
#    'Earth',
#    'crust',
#    'along',
#    'plate',
#    'boundaries',
#    'produces']},
#  {'A': ['igneous'],
#   'B': ['metamorphic'],
#   'C': ['sedimentary'],
#   'D': ['volcanic'],
#   'Q': ['In', 'type', 'rock', 'fossils', 'generally', 'found']},
#  {'A': ['magnet'],
#   'B': ['filter', 'paper'],
#   'C': ['triple', 'beam', 'balance'],
#   'D': ['voltmeter'],
#   'Q': ['Which',
#    'equipment',
#    'best',
#    'separate',
#    'mixture',
#    'iron',
#    'filings',
#    'black',
#    'pepper']},
#  {'A': ['a', 'chemical', 'reaction'],
#   'B': ['a', 'physical', 'change'],
#   'C': ['photosynthesis'],
#   'D': ['evaporation'],
#   'Q': ['Hydrochloric',
#    'acid',
#    'added',
#    'beaker',
#    'containing',
#    'piece',
#    'zinc',
#    'As',
#    'result',
#    'zinc',
#    'chloride',
#    'formed',
#    'hydrogen',
#    'gas',
#    'released',
#    'This',
#    'example']},
#  {'A': ['a', 'Punnett', 'square'],
#   'B': ['the', 'Periodic', 'Table'],
#   'C': ['a', 'pedigree', 'chart'],
#   'D': ['the', 'rock', 'cycle'],
#   'Q': ['Which',
#    'model',
#    'used',
#    'scientists',
#    'determine',
#    'properties',
#    'elements']},
#  {'A': ['fuel', 'oil'],
#   'B': ['natural', 'gas'],
#   'C': ['wind'],
#   'D': ['coal'],
#   'Q': ['Which', 'energy', 'resource', 'renewable']},
#  {'A': ['Most',
#    'of',
#    'the',
#    'leaves',
#    'on',
#    'the',
#    'window',
#    'side',
#    'will',
#    'wilt',
#    'and',
#    'die'],
#   'B': ['The',
#    'roots',
#    'of',
#    'the',
#    'plants',
#    'will',
#    'grow',
#    'upward',
#    'from',
#    'the',
#    'soil'],
#   'C': ['Water',
#    'droplets',
#    'will',
#    'collect',
#    'on',
#    'the',
#    'leaves',
#    'facing',
#    'away',
#    'from',
#    'the',
#    'window'],
#   'D': ['The', 'stem', 'will', 'bend', 'toward', 'the', 'window'],
#   'Q': ['Several',
#    'tomato',
#    'plants',
#    'grown',
#    'indoors',
#    'next',
#    'sunny',
#    'window',
#    'The',
#    'plants',
#    'receive',
#    'water',
#    'fertilizer',
#    'remain',
#    'windowsill',
#    'What',
#    'likely',
#    'happen']},
#  {'A': ['break', 'down', 'foods', 'for', 'absorption', 'into', 'the', 'blood'],
#   'B': ['exchange',
#    'oxygen',
#    'and',
#    'carbon',
#    'dioxide',
#    'in',
#    'the',
#    'lungs'],
#   'C': ['release', 'energy', 'from', 'sugars', 'within', 'the', 'cells'],
#   'D': ['carry', 'nutrients', 'to', 'all', 'parts', 'of', 'the', 'body'],
#   'Q': ['The', 'main', 'function', 'human', 'digestive', 'system']},
#  {'A': ['organ', 'system', 'tissue', 'cell', 'organ'],
#   'B': ['tissue', 'cell', 'organ', 'organ', 'system'],
#   'C': ['organ', 'organ', 'system', 'tissue', 'cell'],
#   'D': ['cell', 'tissue', 'organ', 'organ', 'system'],
#   'Q': ['Which',
#    'sequence',
#    'lists',
#    'levels',
#    'organization',
#    'human',
#    'body',
#    'simplest',
#    'complex']},
#  {'A': ['nervous', 'skeletal', 'and', 'muscular'],
#   'B': ['muscular', 'endocrine', 'and', 'excretory'],
#   'C': ['digestive', 'excretory', 'and', 'reproductive'],
#   'D': ['circulatory', 'endocrine', 'and', 'respiratory'],
#   'Q': ['Which',
#    'three',
#    'systems',
#    'human',
#    'body',
#    'function',
#    'together',
#    'move',
#    'control',
#    'body',
#    'parts']},
#  {'A': ['particles', 'in', 'the', 'air'],
#   'B': ['rocks', 'containing', 'fossils'],
#   'C': ['tree', 'rings', 'from', 'recently', 'logged', 'trees'],
#   'D': ['chemicals', 'in', 'human', 'hair'],
#   'Q': ['Evidence',
#    'living',
#    'things',
#    'evolved',
#    'hundreds',
#    'millions',
#    'years',
#    'found']},
#  {'A': ['evolution'],
#   'B': ['migration'],
#   'C': ['selective', 'breeding'],
#   'D': ['environmental', 'changes'],
#   'Q': ['Extinction', 'species', 'likely', 'occur', 'result']},
#  {'A': ['adaptation'],
#   'B': ['developmental', 'stages'],
#   'C': ['a', 'habit'],
#   'D': ['selective', 'breeding'],
#   'Q': ['Some',
#    'kinds',
#    'fish',
#    'live',
#    'lives',
#    'salt',
#    'water',
#    'lay',
#    'eggs',
#    'freshwater',
#    'Their',
#    'ability',
#    'survive',
#    'different',
#    'environments',
#    'example']},
#  {'A': ['yeast', 'cells', 'splitting', 'into', 'new', 'cells'],
#   'B': ['bacteria', 'cells', 'dividing', 'into', 'new', 'cells'],
#   'C': ['skin', 'cells', 'dividing', 'to', 'produce', 'more', 'skin', 'cells'],
#   'D': ['sperm',
#    'and',
#    'egg',
#    'cells',
#    'uniting',
#    'to',
#    'produce',
#    'fertilized',
#    'egg',
#    'cells'],
#   'Q': ['Which',
#    'example',
#    'would',
#    'result',
#    'new',
#    'cells',
#    'different',
#    'parent',
#    'cells']},
#  {'A': ['excretion'],
#   'B': ['locomotion'],
#   'C': ['cell', 'division'],
#   'D': ['decomposition'],
#   'Q': ['Growth', 'repair', 'multicellular', 'organisms', 'result']},
#  {'A': ['a', 'strong', 'sweet', 'smell'],
#   'B': ['a', 'dry', 'rough', 'texture'],
#   'C': ['a', 'green', 'color'],
#   'D': ['a', 'smooth', 'stem'],
#   'Q': ['Which',
#    'observation',
#    'plant',
#    'supports',
#    'inference',
#    'photosynthesis',
#    'take',
#    'place']},
#  {'A': ['community'],
#   'B': ['system'],
#   'C': ['habitat'],
#   'D': ['species'],
#   'Q': ['Populations', 'living', 'one', 'place', 'form']},
#  {'A': ['An', 'organism', 'survives', 'a', 'difficult', 'winter'],
#   'B': ['The', 'populations', 'in', 'an', 'area', 'remain', 'the', 'same'],
#   'C': ['One',
#    'species',
#    'replaces',
#    'another',
#    'species',
#    'in',
#    'an',
#    'ecosystem'],
#   'D': ['Each',
#    'of',
#    'several',
#    'species',
#    'uses',
#    'the',
#    'same',
#    'amount',
#    'of',
#    'resources'],
#   'Q': ['Which', 'situation', 'best', 'example', 'ecological', 'succession']},
#  {'A': ['asexual', 'reproduction'],
#   'B': ['cloning'],
#   'C': ['metamorphosis'],
#   'D': ['biological', 'adaptation'],
#   'Q': ['Young',
#    'frogs',
#    'resemble',
#    'adult',
#    'frogs',
#    'Which',
#    'term',
#    'given',
#    'pattern',
#    'development',
#    'frogs']},
#  {'A': ['hydrogen', 'helium', 'and', 'water', 'vapor'],
#   'B': ['hydrogen', 'methane', 'and', 'ozone'],
#   'C': ['carbon', 'dioxide', 'water', 'vapor', 'and', 'nitrogen'],
#   'D': ['carbon', 'dioxide', 'methane', 'and', 'helium'],
#   'Q': ['In',
#    'addition',
#    'oxygen',
#    'gases',
#    'make',
#    'largest',
#    'percentage',
#    'Earth',
#    'atmosphere']},
#  {'A': ['potential', 'energy'],
#   'B': ['efficiency'],
#   'C': ['output'],
#   'D': ['friction'],
#   'Q': ['The', 'wheels', 'gears', 'machine', 'greased', 'order', 'decrease']},
#  {'A': ['global', 'warming'],
#   'B': ['air', 'quality', 'control'],
#   'C': ['plate', 'tectonics'],
#   'D': ['use', 'of', 'images', 'from', 'space'],
#   'Q': ['Weather', 'forecasts', 'accurate', 'today', 'past', 'due']},
#  {'A': ['their', 'color'],
#   'B': ['their', 'shape'],
#   'C': ['how', 'they', 'formed'],
#   'D': ['the', 'minerals', 'they', 'contain'],
#   'Q': ['Rocks',
#    'classified',
#    'igneous',
#    'metamorphic',
#    'sedimentary',
#    'according']},
#  {'A': ['Use', 'tweezers', 'to', 'separate', 'them'],
#   'B': ['Use', 'a', 'magnet', 'to', 'separate', 'them'],
#   'C': ['Add', 'water', 'to', 'the', 'mixture'],
#   'D': ['Pour', 'the', 'mixture', 'into', 'a', 'filter'],
#   'Q': ['Sand',
#    'iron',
#    'particles',
#    'similar',
#    'size',
#    'color',
#    'mixed',
#    'together',
#    'beaker',
#    'What',
#    'would',
#    'best',
#    'method',
#    'separating',
#    'particles']},
#  {'A': ['crushing', 'a', 'rock'],
#   'B': ['burning', 'a', 'piece', 'of', 'wood'],
#   'C': ['mixing', 'salt', 'and', 'pepper'],
#   'D': ['melting', 'an', 'ice', 'cube'],
#   'Q': ['Which', 'action', 'forms', 'different', 'chemical', 'substance']},
#  {'A': ['provide', 'nutrients', 'for', 'the', 'growing', 'corn', 'plant'],
#   'B': ['eliminate',
#    'the',
#    'need',
#    'for',
#    'weeding',
#    'around',
#    'the',
#    'corn',
#    'plant'],
#   'C': ['release', 'oxygen', 'for', 'use', 'by', 'the', 'corn', 'plant'],
#   'D': ['supply',
#    'all',
#    'the',
#    'water',
#    'needed',
#    'by',
#    'the',
#    'corn',
#    'plant'],
#   'Q': ['In',
#    'past',
#    'Native',
#    'American',
#    'Indians',
#    'buried',
#    'dead',
#    'fish',
#    'along',
#    'corn',
#    'seeds',
#    'This',
#    'technique',
#    'used',
#    'decomposing',
#    'dead',
#    'fish',
#    'would']},
#  {'A': ['are', 'microscopic'],
#   'B': ['do', 'not', 'contain', 'DNA'],
#   'C': ['reproduce', 'very', 'quickly'],
#   'D': ['cause', 'infectious', 'diseases'],
#   'Q': ['Although',
#    'change',
#    'multicellular',
#    'species',
#    'usually',
#    'takes',
#    'thousands',
#    'years',
#    'species',
#    'bacteria',
#    'undergo',
#    'major',
#    'changes',
#    'years',
#    'One',
#    'reason',
#    'difference',
#    'bacteria']},
#  {'A': ['deer', 'and', 'butterflies'],
#   'B': ['owls', 'and', 'bacteria'],
#   'C': ['goldfish', 'and', 'rabbits'],
#   'D': ['grass', 'and', 'strawberry', 'plants'],
#   'Q': ['Competition', 'likely', 'occur', 'two', 'organisms']},
#  {'A': ['hormones'],
#   'B': ['DNA', 'molecules'],
#   'C': ['minerals', 'and', 'water'],
#   'D': ['undigested', 'food', 'molecules'],
#   'Q': ['Many',
#    'cells',
#    'nucleus',
#    'contains',
#    'chromosomes',
#    'These',
#    'chromosomes',
#    'carry',
#    'genes',
#    'composed']},
#  {'A': ['beneficial', 'only'],
#   'B': ['harmful', 'only'],
#   'C': ['beneficial', 'or', 'harmful'],
#   'Q': ['Some',
#    'microorganisms',
#    'cause',
#    'human',
#    'disease',
#    'Other',
#    'microorganisms',
#    'used',
#    'making',
#    'cheese',
#    'yogurt',
#    'bread',
#    'Based',
#    'information',
#    'relationship',
#    'humans',
#    'microorganisms']},
#  {'A': ['Energy', 'for', 'cell', 'processes', 'is', 'released'],
#   'B': ['Oxygen', 'is', 'released', 'for', 'photosynthesis'],
#   'C': ['Cells', 'undergo', 'decomposition'],
#   'D': ['Nutrients',
#    'are',
#    'excreted',
#    'to',
#    'prevent',
#    'the',
#    'buildup',
#    'of',
#    'body',
#    'fat'],
#   'Q': ['What', 'result', 'cellular', 'respiration']},
#  {'A': ['hunting', 'and', 'killing', 'prey', 'for', 'food'],
#   'B': ['changing', 'carbon', 'dioxide', 'and', 'water', 'into', 'food'],
#   'C': ['absorbing', 'food', 'from', 'dead', 'organisms'],
#   'D': ['producing', 'food', 'from', 'oxygen', 'and', 'sunlight'],
#   'Q': ['How', 'decomposers', 'obtain', 'food']},
#  {'A': ['their', 'speed', 'of', 'movement'],
#   'B': ['the', 'size', 'of', 'their', 'communities'],
#   'C': ['how', 'they', 'obtain', 'food'],
#   'D': ['how', 'they', 'reproduce'],
#   'Q': ['Living',
#    'things',
#    'classified',
#    'producers',
#    'consumers',
#    'according']},
#  {'A': ['cell', 'tissue', 'organ', 'organ', 'system'],
#   'B': ['organ', 'system', 'cell', 'tissue', 'organ'],
#   'C': ['tissue', 'organ', 'organ', 'system', 'cell'],
#   'D': ['cell', 'organ', 'tissue', 'organ', 'system'],
#   'Q': ['Which',
#    'sequence',
#    'correctly',
#    'shows',
#    'levels',
#    'organization',
#    'structure',
#    'function',
#    'human']},
#  {'A': ['adaptations', 'for', 'flight'],
#   'B': ['responses', 'to', 'stimuli'],
#   'C': ['unnecessary', 'body', 'parts'],
#   'D': ['reproductive', 'structures'],
#   'Q': ['Feathers', 'wings', 'hollow', 'bones', 'birds', 'examples']},
#  {'A': ['identical', 'to', 'the', 'parent'],
#   'B': ['different', 'from', 'the', 'parent'],
#   'C': ['different', 'from', 'each', 'other'],
#   'D': ['formed', 'by', 'two', 'parents'],
#   'Q': ['Asexually', 'produced', 'offspring', 'genetically']},
#  {'A': ['one', 'quarter', 'the', 'amount'],
#   'B': ['one', 'half', 'the', 'amount'],
#   'C': ['the', 'same', 'amount'],
#   'D': ['twice', 'the', 'amount'],
#   'Q': ['Compared',
#    'amount',
#    'hereditary',
#    'information',
#    'human',
#    'body',
#    'cell',
#    'much',
#    'hereditary',
#    'information',
#    'contained',
#    'human',
#    'sex',
#    'cell']},
#  {'A': ['bacteria'],
#   'B': ['birds'],
#   'C': ['fish'],
#   'D': ['reptiles'],
#   'Q': ['Which',
#    'group',
#    'organisms',
#    'show',
#    'significant',
#    'trait',
#    'changes',
#    'shortest',
#    'period',
#    'time']},
#  {'A': ['sexual', 'reproduction'],
#   'B': ['asexual', 'reproduction'],
#   'C': ['evolution'],
#   'D': ['extinction'],
#   'Q': ['A',
#    'plant',
#    'produces',
#    'tiny',
#    'plants',
#    'around',
#    'edges',
#    'leaves',
#    'When',
#    'tiny',
#    'plants',
#    'fall',
#    'ground',
#    'take',
#    'root',
#    'become',
#    'new',
#    'plants',
#    'This',
#    'process',
#    'example']},
#  {'A': ['reproduction'],
#   'B': ['extinction'],
#   'C': ['locomotion'],
#   'D': ['regulation'],
#   'Q': ['Which',
#    'term',
#    'describes',
#    'organism',
#    'ability',
#    'maintain',
#    'stable',
#    'internal',
#    'environment']},
#  {'A': ['extinction'],
#   'B': ['mutation'],
#   'C': ['selective', 'breeding'],
#   'D': ['natural', 'selection'],
#   'Q': ['A',
#    'research',
#    'team',
#    'wanted',
#    'produce',
#    'smaller',
#    'variety',
#    'German',
#    'shepherd',
#    'dogs',
#    'They',
#    'mated',
#    'smallest',
#    'dogs',
#    'different',
#    'litters',
#    'several',
#    'generations',
#    'This',
#    'example',
#    'concept']},
#  {'A': ['growth', 'and', 'repair'],
#   'B': ['sexual', 'reproduction'],
#   'C': ['obtaining', 'energy'],
#   'D': ['production', 'of', 'sex', 'cells'],
#   'Q': ['In', 'animal', 'skin', 'tissue', 'cell', 'division', 'responsible']},
#  {'A': ['Stem',
#    'cuttings',
#    'are',
#    'placed',
#    'in',
#    'water',
#    'and',
#    'grow',
#    'roots'],
#   'B': ['Seeds',
#    'are',
#    'produced',
#    'from',
#    'the',
#    'flower',
#    'of',
#    'the',
#    'plant'],
#   'C': ['Underground',
#    'stems',
#    'from',
#    'a',
#    'plant',
#    'grow',
#    'into',
#    'new',
#    'plants'],
#   'D': ['A',
#    'leaf',
#    'falls',
#    'to',
#    'the',
#    'soil',
#    'develops',
#    'roots',
#    'and',
#    'grows'],
#   'Q': ['Which',
#    'statement',
#    'describes',
#    'method',
#    'sexual',
#    'reproduction',
#    'occurs',
#    'plants']},
#  {'A': ['ounce'],
#   'B': ['degree'],
#   'C': ['calorie'],
#   'D': ['gram'],
#   'Q': ['Which', 'unit', 'used', 'indicate', 'amount', 'energy', 'food']},
#  {'A': ['produce', 'carbon', 'dioxide'],
#   'B': ['remove', 'oxygen', 'from', 'the', 'air'],
#   'C': ['are', 'producers'],
#   'D': ['are', 'consumers'],
#   'Q': ['All', 'living', 'organisms', 'dependent', 'plants', 'plants']},
#  {'A': ['grasses', 'trees', 'bushes'],
#   'B': ['trees', 'bushes', 'grasses'],
#   'C': ['bushes', 'grasses', 'trees'],
#   'D': ['grasses', 'bushes', 'trees'],
#   'Q': ['Which',
#    'order',
#    'succession',
#    'natural',
#    'communities',
#    'would',
#    'likely',
#    'occur',
#    'New',
#    'York',
#    'State']},
#  {'A': ['a', 'conveyor', 'belt', 'that', 'transports', 'materials'],
#   'B': ['a',
#    'storage',
#    'bin',
#    'that',
#    'holds',
#    'the',
#    'pieces',
#    'needed',
#    'to',
#    'assemble',
#    'a',
#    'car'],
#   'C': ['the',
#    'computer',
#    'room',
#    'that',
#    'controls',
#    'the',
#    'assembly',
#    'process'],
#   'D': ['the',
#    'generator',
#    'that',
#    'provides',
#    'energy',
#    'for',
#    'the',
#    'factory'],
#   'Q': ['The',
#    'structures',
#    'found',
#    'living',
#    'cell',
#    'compared',
#    'parts',
#    'factory',
#    'produces',
#    'cars',
#    'Which',
#    'part',
#    'factory',
#    'similar',
#    'nucleus',
#    'living',
#    'cell']},
#  {'A': ['fossils'],
#   'B': ['cells'],
#   'C': ['metals'],
#   'D': ['minerals'],
#   'Q': ['All', 'rocks', 'composed']},
#  {'A': ['a', 'piece', 'of', 'clear', 'glass'],
#   'B': ['a', 'snowball'],
#   'C': ['a', 'shiny', 'mirror'],
#   'D': ['a', 'black', 'sweater'],
#   'Q': ['When',
#    'placed',
#    'direct',
#    'sunlight',
#    'object',
#    'absorb',
#    'visible',
#    'light',
#    'energy']},
#  {'A': ['reflected', 'sunlight'],
#   'B': ['absorbed', 'light', 'from', 'Earth', 's', 'atmosphere'],
#   'C': ['gases', 'in', 'the', 'Moon', 's', 'interior'],
#   'D': ['volcanic', 'eruptions', 'on', 'the', 'Moon', 's', 'surface'],
#   'Q': ['The', 'Moon', 'visible', 'observers', 'Earth']},
#  {'A': ['rotation', 'of', 'Earth'],
#   'B': ['rotation', 'of', 'the', 'Sun'],
#   'C': ['revolution', 'of', 'Earth', 'around', 'the', 'Sun'],
#   'D': ['revolution', 'of', 'the', 'Sun', 'around', 'Earth'],
#   'Q': ['The', 'length', 'year', 'equivalent', 'time', 'takes', 'one']},
#  {'A': ['the', 'revolution', 'of', 'the', 'Moon', 'around', 'Earth'],
#   'B': ['the', 'tilt', 'of', 'Earth', 'on', 'its', 'axis'],
#   'C': ['the', 'rising', 'and', 'falling', 'of', 'ocean', 'tides'],
#   'D': ['the', 'distance', 'of', 'Earth', 'from', 'the', 'Sun'],
#   'Q': ['What',
#    'one',
#    'factor',
#    'contributes',
#    'seasons',
#    'occurring',
#    'New',
#    'York',
#    'State']},
#  {'A': ['earthquake', 'activity'],
#   'B': ['local', 'weather', 'changes'],
#   'C': ['global', 'warming'],
#   'D': ['ecological', 'succession'],
#   'Q': ['The', 'movement', 'air', 'mass', 'Earth', 'surface', 'causes']},
#  {'A': ['volcanic', 'eruptions', 'and', 'global', 'warming'],
#   'B': ['earthquakes', 'and', 'tidal', 'activity'],
#   'C': ['collision', 'of', 'crustal', 'plates', 'and', 'erosion'],
#   'D': ['production', 'of', 'greenhouse', 'gases', 'and', 'weathering'],
#   'Q': ['Which',
#    'two',
#    'processes',
#    'could',
#    'result',
#    'formation',
#    'high',
#    'mountains',
#    'well',
#    'rounded',
#    'peaks']},
#  {'A': ['greater',
#    'than',
#    'the',
#    'mass',
#    'of',
#    'the',
#    'carbon',
#    'plus',
#    'the',
#    'mass',
#    'of',
#    'the',
#    'oxygen'],
#   'B': ['equal',
#    'to',
#    'the',
#    'mass',
#    'of',
#    'the',
#    'carbon',
#    'plus',
#    'the',
#    'mass',
#    'of',
#    'the',
#    'oxygen'],
#   'C': ['equal', 'to', 'the', 'mass', 'of', 'the', 'carbon'],
#   'D': ['less', 'than', 'the', 'mass', 'of', 'the', 'carbon'],
#   'Q': ['When',
#    'carbon',
#    'oxygen',
#    'combine',
#    'chemically',
#    'mass',
#    'product']},
#  {'A': ['liquid', 'to', 'gas'],
#   'B': ['gas', 'to', 'solid'],
#   'C': ['liquid', 'to', 'solid'],
#   'D': ['gas', 'to', 'liquid'],
#   'Q': ['During',
#    'phase',
#    'change',
#    'heat',
#    'energy',
#    'absorbed',
#    'substance']},
#  {'A': ['carries', 'dissolved', 'oxygen'],
#   'B': ['easily', 'erodes', 'sediments'],
#   'C': ['is', 'made', 'of', 'natural', 'gas'],
#   'D': ['can', 'be', 'recycled', 'by', 'nature', 'over', 'time'],
#   'Q': ['Moving', 'water', 'river', 'considered', 'renewable', 'resource']},
#  {'A': ['The', 'baseball', 'strikes', 'the', 'roof'],
#   'B': ['The', 'roof', 'of', 'the', 'car', 'dents'],
#   'C': ['The', 'paint', 'cracks', 'and', 'chips'],
#   'D': ['The', 'exposed', 'metal', 'rusts'],
#   'Q': ['Base',
#    'answer',
#    'information',
#    'knowledge',
#    'science',
#    'A',
#    'baseball',
#    'strikes',
#    'roof',
#    'car',
#    'dents',
#    'The',
#    'paint',
#    'roof',
#    'begins',
#    'crack',
#    'chip',
#    'exposing',
#    'metal',
#    'The',
#    'exposed',
#    'metal',
#    'roof',
#    'rusts',
#    'eventually',
#    'causing',
#    'small',
#    'hole',
#    'roof',
#    'Which',
#    'event',
#    'chemical',
#    'change']},
#  {'A': ['Cover', 'it'],
#   'B': ['Heat', 'it'],
#   'C': ['Place', 'it', 'in', 'the', 'dark'],
#   'D': ['Put', 'salt', 'in', 'it'],
#   'Q': ['Water',
#    '20',
#    'C',
#    'uncovered',
#    'pan',
#    'evaporating',
#    'slowly',
#    'What',
#    'could',
#    'done',
#    'water',
#    'make',
#    'evaporate',
#    'quickly']},
#  {'A': ['year'],
#   'B': ['seasons'],
#   'C': ['ocean', 'tides'],
#   'D': ['daylight', 'hours'],
#   'Q': ['The', 'Moon', 'greatest', 'effect', 'Earth']},
#  {'A': ['yellow', 'color'],
#   'B': ['high', 'temperature'],
#   'C': ['distance', 'from', 'Earth'],
#   'D': ['chemical', 'composition'],
#   'Q': ['The', 'Sun', 'appears', 'larger', 'stars']},
#  {'A': ['Earth', 's', 'rotation'],
#   'B': ['Earth', 's', 'revolution'],
#   'C': ['the', 'Moon', 's', 'rotation'],
#   'D': ['the', 'Moon', 's', 'revolution'],
#   'Q': ['The',
#    'longitude',
#    'location',
#    'determines',
#    'time',
#    'zone',
#    'Different',
#    'time',
#    'zones',
#    'result']},
#  {'A': ['north'],
#   'B': ['south'],
#   'C': ['east'],
#   'D': ['west'],
#   'Q': ['In',
#    'New',
#    'York',
#    'State',
#    'observer',
#    'usually',
#    'see',
#    'Sun',
#    'rise']},
#  {'A': ['blizzard'],
#   'B': ['hurricane'],
#   'C': ['thunderstorm'],
#   'D': ['tornado'],
#   'Q': ['Which',
#    'weather',
#    'event',
#    'usually',
#    'includes',
#    'heavy',
#    'precipitation',
#    'strong',
#    'winds',
#    'surface',
#    'air',
#    'temperatures',
#    '0',
#    'C']},
#  {'A': ['erosion'],
#   'B': ['conduction'],
#   'C': ['condensation'],
#   'D': ['precipitation'],
#   'Q': ['Which', 'process', 'must', 'occur', 'clouds', 'form']},
#  {'A': ['cells'],
#   'B': ['molecules'],
#   'C': ['atoms'],
#   'D': ['compounds'],
#   'Q': ['All', 'matter', 'made', 'particles', 'called']},
#  {'A': ['electrical', 'light', 'chemical'],
#   'B': ['electrical', 'chemical', 'light'],
#   'C': ['chemical', 'light', 'electrical'],
#   'D': ['chemical', 'electrical', 'light'],
#   'Q': ['Which',
#    'sequence',
#    'energy',
#    'transformations',
#    'occurs',
#    'battery',
#    'operated',
#    'flashlight',
#    'turned']},
#  {'A': ['oil'],
#   'B': ['moving', 'water'],
#   'C': ['sunlight'],
#   'D': ['biomass'],
#   'Q': ['Which', 'energy', 'source', 'considered', 'nonrenewable']},
#  {'A': ['a', 'magnetic', 'force'],
#   'B': ['a', 'heat', 'transfer'],
#   'C': ['a', 'chemical', 'change'],
#   'D': ['an', 'electrical', 'charge'],
#   'Q': ['A',
#    'boy',
#    'pulls',
#    'sweater',
#    'head',
#    'His',
#    'hair',
#    'attracted',
#    'sweater',
#    'due']},
#  {'A': ['mass'],
#   'B': ['volume'],
#   'C': ['pressure'],
#   'D': ['temperature'],
#   'Q': ['The',
#    'gravitational',
#    'force',
#    'two',
#    'objects',
#    'depends',
#    'distance',
#    'objects',
#    'object']},
#  {'A': ['were', 'formed', 'from', 'different', 'fossils'],
# ...
#    'and',
#    'energy'],
#   'Q': ['Why', 'healthy', 'diet', 'important']},
#  {'A': ['They',
#    'move',
#    'faster',
#    'and',
#    'move',
#    'farther',
#    'apart',
#    'as',
#    'they',
#    'absorb',
#    'heat'],
#   'B': ['They',
#    'move',
#    'faster',
#    'and',
#    'remain',
#    'close',
#    'together',
#    'as',
#    'they',
#    'absorb',
#    'heat'],
#   'C': ['They',
#    'move',
#    'more',
#    'slowly',
#    'but',
#    'move',
#    'farther',
#    'apart',
#    'as',
#    'they',
#    'lose',
#    'heat'],
#   'D': ['They',
#    'move',
#    'faster',
#    'and',
#    'move',
#    'farther',
#    'apart',
#    'as',
#    'they',
#    'lose',
#    'heat'],
#   'Q': ['What', 'happens', 'water', 'molecules', 'boiling', 'process']},
#  {'A': ['Li', 'and', 'B'],
#   'B': ['I', 'and', 'Ca'],
#   'C': ['K', 'and', 'He'],
#   'D': ['N', 'and', 'P'],
#   'Q': ['Which', 'pair', 'elements', 'similar', 'properties']},
#  {'A': ['12', 'atoms', 'of', 'carbon', 'C'],
#   'B': ['6', 'atoms', 'of', 'carbon'],
#   'C': ['C', '3', 'atoms', 'of', 'carbon', 'C'],
#   'D': ['2', 'atoms', 'of', 'carbon'],
#   'Q': ['If',
#    'chemical',
#    'reaction',
#    'photosynthesis',
#    'begins',
#    '6',
#    'atoms',
#    'carbon',
#    'C',
#    'many',
#    'atoms',
#    'carbon',
#    'C',
#    'products']},
#  {'A': ['ecosystem', 'damage', 'and', 'loss', 'of', 'land'],
#   'B': ['reduced', 'carbon', 'dioxide', 'emission'],
#   'C': ['only', 'suitable', 'for', 'industrial', 'use'],
#   'D': ['creates', 'reservoirs'],
#   'Q': ['Which',
#    'possible',
#    'disadvantage',
#    'using',
#    'flowing',
#    'water',
#    'produce',
#    'electricity']},
#  {'A': ['oceanic'],
#   'B': ['intertidal'],
#   'C': ['deep', 'ocean'],
#   'D': ['open', 'ocean'],
#   'Q': ['In',
#    'oceanic',
#    'zone',
#    'clams',
#    'crabs',
#    'survive',
#    'burrowing',
#    'sand']},
#  {'A': ['contact', 'with', 'environmental', 'sources'],
#   'B': ['contact', 'with', 'an', 'infected', 'animal'],
#   'C': ['contact', 'with', 'a', 'contaminated', 'object'],
#   'D': ['contact', 'with', 'an', 'infected', 'person'],
#   'Q': ['Ten',
#    'people',
#    'became',
#    'sick',
#    'flu',
#    'attending',
#    'school',
#    'dance',
#    'What',
#    'scenario',
#    'could',
#    'best',
#    'explain',
#    'people',
#    'got',
#    'sick']},
#  {'A': ['Nitrogen', 'increases', 'protein', 'production', 'in', 'plants'],
#   'B': ['Nitrogen', 'decreases', 'protein', 'production', 'in', 'plants'],
#   'C': ['Nitrogen',
#    'decreases',
#    'the',
#    'effectiveness',
#    'of',
#    'photosynthesis'],
#   'D': ['Nitrogen',
#    'increases',
#    'the',
#    'effectiveness',
#    'of',
#    'photosynthesis'],
#   'Q': ['Which',
#    'best',
#    'explains',
#    'importance',
#    'nitrogen',
#    'cycling',
#    'energy',
#    'matter']},
#  {'A': ['by', 'producing', 'crops', 'that', 'are', 'virus', 'resistant'],
#   'B': ['by',
#    'making',
#    'robots',
#    'to',
#    'replace',
#    'large',
#    'farm',
#    'machines'],
#   'C': ['by',
#    'reducing',
#    'the',
#    'need',
#    'for',
#    'countries',
#    'to',
#    'import',
#    'food'],
#   'D': ['by',
#    'increasing',
#    'the',
#    'use',
#    'of',
#    'wind',
#    'farms',
#    'that',
#    'produce',
#    'electricity'],
#   'Q': ['Which',
#    'way',
#    'agricultural',
#    'biotechnology',
#    'industry',
#    'could',
#    'positive',
#    'impact',
#    'environment']},
#  {'A': ['The', 'population', 'of', 'deer', 'will', 'increase'],
#   'B': ['The', 'population', 'of', 'deer', 'will', 'decrease'],
#   'C': ['The', 'population', 'of', 'deer', 'will', 'remain', 'the', 'same'],
#   'D': ['The', 'population', 'of', 'deer', 'will', 'become', 'extinct'],
#   'Q': ['If',
#    'wolves',
#    'prey',
#    'deer',
#    'food',
#    'likely',
#    'happen',
#    'deer',
#    'population',
#    'wolves',
#    'removed',
#    'area',
#    'deer',
#    'live']},
#  {'A': ['They', 'swim', 'the', 'same', 'way'],
#   'B': ['They', 'eat', 'the', 'same', 'food'],
#   'C': ['They', 'live', 'in', 'the', 'same', 'area', 'of', 'the', 'ocean'],
#   'D': ['They', 'have', 'similar', 'anatomies'],
#   'Q': ['Scientists',
#    'think',
#    'dolphins',
#    'whales',
#    'may',
#    'evolved',
#    'common',
#    'ancestor',
#    'What',
#    'evidence',
#    'supports',
#    'hypothesis']},
#  {'A': ['Wind',
#    'turbines',
#    'are',
#    'efficient',
#    'only',
#    'in',
#    'certain',
#    'areas'],
#   'B': ['Wind', 'turbines', 'occupy', 'a', 'small', 'area', 'of', 'land'],
#   'C': ['Wind', 'turbines', 'produce', 'a', 'large', 'amount', 'of', 'energy'],
#   'D': ['Wind',
#    'turbines',
#    'create',
#    'a',
#    'large',
#    'amount',
#    'of',
#    'pollution'],
#   'Q': ['Which', 'problem', 'using', 'wind', 'turbines', 'produce', 'energy']},
#  {'A': ['type', 'of', 'soil', 'and', 'salinity'],
#   'B': ['nitrate', 'levels', 'and', 'turbidity'],
#   'C': ['human', 'consumption', 'and', 'pH'],
#   'D': ['natural', 'disasters', 'and', 'tidal', 'changes'],
#   'Q': ['Which',
#    'factors',
#    'greatest',
#    'effect',
#    'health',
#    'river',
#    'system']},
#  {'A': ['Earth', 's', 'climate', 'is', 'constantly', 'changing'],
#   'B': ['The', 'continents', 'of', 'Earth', 'are', 'continually', 'moving'],
#   'C': ['Dinosaurs',
#    'became',
#    'extinct',
#    'about',
#    '65',
#    'million',
#    'years',
#    'ago'],
#   'D': ['The',
#    'oceans',
#    'are',
#    'much',
#    'deeper',
#    'today',
#    'than',
#    'millions',
#    'years',
#    'ago'],
#   'Q': ['What', 'earthquakes', 'tell', 'scientists', 'history', 'planet']},
#  {'A': ['Freshwater', 'rivers', 'flow', 'to', 'the', 'ocean'],
#   'B': ['Saltwater',
#    'fish',
#    'are',
#    'found',
#    'in',
#    'some',
#    'mountain',
#    'streams'],
#   'C': ['Dinosaur',
#    'bones',
#    'have',
#    'been',
#    'discovered',
#    'in',
#    'the',
#    'mountains'],
#   'D': ['Marine',
#    'fossils',
#    'have',
#    'been',
#    'found',
#    'on',
#    'the',
#    'peaks',
#    'of',
#    'some',
#    'mountains'],
#   'Q': ['How', 'scientists', 'know', 'mountains', 'bottom', 'ocean']},
#  {'A': ['a', 'virus'],
#   'B': ['a', 'bacterium'],
#   'C': ['a', 'fungus'],
#   'D': ['a', 'parasite'],
#   'Q': ['Malaria',
#    'common',
#    'disease',
#    'many',
#    'countries',
#    'What',
#    'cause',
#    'disease']},
#  {'A': ['allowing', 'them', 'to', 'reproduce', 'freely'],
#   'B': ['changing', 'their', 'food', 'source'],
#   'C': ['using', 'biotechnology', 'techniques'],
#   'D': ['growing', 'them', 'on', 'selected', 'plants'],
#   'Q': ['What',
#    'involved',
#    'creating',
#    'genetically',
#    'modified',
#    'bacteria']},
#  {'A': ['Consumers',
#    'at',
#    'the',
#    'lower',
#    'level',
#    'require',
#    'more',
#    'energy',
#    'than',
#    'the',
#    'top',
#    'level',
#    'consumers'],
#   'B': ['Consumers',
#    'at',
#    'the',
#    'top',
#    'level',
#    'require',
#    'more',
#    'energy',
#    'than',
#    'the',
#    'lower',
#    'level',
#    'consumers'],
#   'C': ['The',
#    'consumers',
#    'are',
#    'feeding',
#    'on',
#    'larger',
#    'organisms',
#    'that',
#    'have',
#    'less',
#    'energy'],
#   'D': ['The',
#    'consumers',
#    'are',
#    'feeding',
#    'on',
#    'smaller',
#    'organisms',
#    'that',
#    'have',
#    'less',
#    'energy'],
#   'Q': ['In',
#    'food',
#    'pyramid',
#    'best',
#    'explains',
#    'number',
#    'organisms',
#    'decreases',
#    'one',
#    'trophic',
#    'level',
#    'next']},
#  {'A': ['They',
#    'have',
#    'larger',
#    'leaves',
#    'to',
#    'protect',
#    'the',
#    'fruit',
#    'than',
#    'the',
#    'other',
#    'strawberries'],
#   'B': ['They',
#    'have',
#    'different',
#    'genetic',
#    'variations',
#    'that',
#    'cause',
#    'them',
#    'to',
#    'be',
#    'more',
#    'resistant',
#    'to',
#    'cold',
#    'temperatures'],
#   'C': ['They',
#    'are',
#    'able',
#    'to',
#    'reproduce',
#    'more',
#    'quickly',
#    'than',
#    'the',
#    'other',
#    'strawberries'],
#   'D': ['The',
#    'color',
#    'of',
#    'the',
#    'strawberries',
#    'is',
#    'darker',
#    'and',
#    'they',
#    'maintain',
#    'their',
#    'temperature',
#    'better',
#    'than',
#    'other',
#    'strawberries'],
#   'Q': ['A',
#    'strawberry',
#    'farmer',
#    'finds',
#    'hard',
#    'freeze',
#    'strawberries',
#    'still',
#    'alive',
#    'Which',
#    'best',
#    'explains',
#    'strawberries',
#    'able',
#    'survive']},
#  {'A': ['potato'],
#   'B': ['meat'],
#   'C': ['milk'],
#   'D': ['fruit'],
#   'Q': ['Which',
#    'food',
#    'provides',
#    'energy',
#    'body',
#    'shortest',
#    'amount',
#    'time']},
#  {'A': ['It', 'is', 'needed', 'to', 'change', 'glucose', 'to', 'energy'],
#   'B': ['It', 'is', 'needed', 'to', 'store', 'nutrients'],
#   'C': ['It', 'is', 'needed', 'to', 'repair', 'tissue'],
#   'D': ['It', 'is', 'needed', 'to', 'produce', 'water'],
#   'Q': ['Why', 'protein', 'important', 'part', 'healthy', 'diet']},
#  {'A': ['its', 'depth', 'and', 'width'],
#   'B': ['its', 'temperature', 'and', 'pH'],
#   'C': ['its', 'location', 'and', 'depth'],
#   'D': ['its', 'temperature', 'and', 'depth'],
#   'Q': ['Which',
#    'best',
#    'determines',
#    'health',
#    'lake',
#    'used',
#    'source',
#    'freshwater']},
#  {'A': ['the', 'birds', 'living', 'in', 'the', 'area', 'of', 'the', 'bones'],
#   'B': ['the',
#    'weather',
#    'conditions',
#    'in',
#    'the',
#    'area',
#    'of',
#    'the',
#    'bones'],
#   'C': ['the',
#    'kinds',
#    'of',
#    'trees',
#    'living',
#    'in',
#    'the',
#    'area',
#    'of',
#    'the',
#    'bones'],
#   'D': ['the', 'index', 'fossils', 'in', 'the', 'area', 'of', 'the', 'bones'],
#   'Q': ['A',
#    'scientist',
#    'finds',
#    'bones',
#    'dinosaur',
#    'What',
#    'could',
#    'help',
#    'scientist',
#    'determine',
#    'approximate',
#    'age',
#    'dinosaur',
#    'bones']},
#  {'A': ['2', 'm', 'of', 'bricks'],
#   'B': ['4', 'm', 'of', 'bricks'],
#   'C': ['6000', 'm', 'of', 'air'],
#   'D': ['10', '000', 'm', 'of', 'air'],
#   'Q': ['Red',
#    'clay',
#    'bricks',
#    'density',
#    'approximately',
#    '2000',
#    'kg',
#    'Air',
#    'density',
#    '1',
#    'kg',
#    'Which',
#    'following',
#    'lowest',
#    'mass']},
#  {'A': ['40'],
#   'B': ['40', 'm', 'north'],
#   'C': ['40', 'm', 's'],
#   'D': ['40', 'm', 's', 'north'],
#   'Q': ['Which', 'following', 'represents', 'velocity', 'moving', 'object']},
#  {'A': ['the', 'speed'],
#   'B': ['the', 'position'],
#   'C': ['the', 'direction'],
#   'D': ['the', 'acceleration'],
#   'Q': ['Which',
#    'characteristic',
#    'motion',
#    'could',
#    'change',
#    'without',
#    'changing',
#    'velocity',
#    'object']},
#  {'A': ['flatten', 'due', 'to', 'the', 'forces'],
#   'B': ['fall', 'at', 'a', 'constant', 'speed'],
#   'C': ['continue', 'to', 'speed', 'up'],
#   'D': ['slow', 'to', 'a', 'stop'],
#   'Q': ['A',
#    'ball',
#    'dropped',
#    'top',
#    'tall',
#    'building',
#    'As',
#    'ball',
#    'falls',
#    'upward',
#    'force',
#    'air',
#    'resistance',
#    'becomes',
#    'equal',
#    'downward',
#    'pull',
#    'gravity',
#    'When',
#    'two',
#    'forces',
#    'become',
#    'equal',
#    'magnitude',
#    'ball']},
#  {'A': ['512', 'g', 'mL'],
#   'B': ['32', 'g', 'mL'],
#   'C': ['8', 'g', 'mL'],
#   'D': ['4', 'g', 'mL'],
#   'Q': ['What',
#    'density',
#    '64',
#    'g',
#    'iron',
#    'cube',
#    'displaces',
#    '8',
#    'mL',
#    'water']},
#  {'A': ['protons',
#    'and',
#    'electrons',
#    'grouped',
#    'together',
#    'in',
#    'a',
#    'random',
#    'pattern'],
#   'B': ['protons',
#    'and',
#    'electrons',
#    'grouped',
#    'together',
#    'in',
#    'an',
#    'alternating',
#    'pattern'],
#   'C': ['a',
#    'core',
#    'of',
#    'protons',
#    'and',
#    'neutrons',
#    'surrounded',
#    'by',
#    'electrons'],
#   'D': ['a',
#    'core',
#    'of',
#    'electrons',
#    'and',
#    'neutrons',
#    'surrounded',
#    'by',
#    'protons'],
#   'Q': ['Which', 'following', 'best', 'describes', 'atom']},
#  {'A': ['a', 'solution'],
#   'B': ['a', 'mixture'],
#   'C': ['a', 'compound'],
#   'D': ['an', 'element'],
#   'Q': ['When',
#    'magnesium',
#    'Mg',
#    'metal',
#    'burned',
#    'presence',
#    'oxygen',
#    'O',
#    'magnesium',
#    'oxide',
#    'MgO',
#    'produced',
#    'The',
#    'properties',
#    'magnesium',
#    'oxide',
#    'different',
#    'individual',
#    'properties',
#    'magnesium',
#    'oxygen',
#    'magnesium',
#    'oxide']},
#  {'A': ['liquid'],
#   'B': ['solid'],
#   'C': ['gas'],
#   'D': ['crystal'],
#   'Q': ['Within',
#    'substance',
#    'atoms',
#    'collide',
#    'frequently',
#    'move',
#    'independently',
#    'one',
#    'another',
#    'likely']},
#  {'A': ['I', 'and', 'O'],
#   'B': ['Ir', 'and', 'O'],
#   'C': ['Fe', 'and', 'O'],
#   'D': ['Pb', 'and', 'O'],
#   'Q': ['ron',
#    'oxides',
#    'rust',
#    'form',
#    'iron',
#    'metal',
#    'reacts',
#    'oxygen',
#    'air',
#    'What',
#    'chemical',
#    'symbols',
#    'two',
#    'elements',
#    'found',
#    'iron',
#    'oxide']},
#  {'A': ['They', 'are', 'noble', 'inert', 'gases'],
#   'B': ['They', 'are', 'nonmetals'],
#   'C': ['They', 'have', 'the', 'same', 'thermal', 'conductivity'],
#   'D': ['They', 'have', 'the', 'same', 'number', 'of', 'protons'],
#   'Q': ['What',
#    'elements',
#    'sulfur',
#    'S',
#    'nitrogen',
#    'N',
#    'phosphorus',
#    'P',
#    'bromine',
#    'Br',
#    'common']},
#  {'A': ['weight'],
#   'B': ['density'],
#   'C': ['conductivity'],
#   'D': ['mass'],
#   'Q': ['A',
#    'student',
#    'divides',
#    'several',
#    'cubes',
#    'two',
#    'groups',
#    'based',
#    'whether',
#    'cube',
#    'float',
#    'later',
#    'What',
#    'property',
#    'student',
#    'using',
#    'classify',
#    'cubes']},
#  {'A': ['hundreds', 'of', 'stars'],
#   'B': ['thousands', 'of', 'stars'],
#   'C': ['millions', 'of', 'stars'],
#   'D': ['billions', 'of', 'stars'],
#   'Q': ['A', 'galaxy', 'best', 'described', 'cluster']},
#  {'A': ['meter'],
#   'B': ['kilometer'],
#   'C': ['light', 'year'],
#   'D': ['astronomical', 'unit'],
#   'Q': ['To',
#    'express',
#    'distance',
#    'Milky',
#    'Way',
#    'galaxy',
#    'galaxies',
#    'appropriate',
#    'unit',
#    'measurement']},
#  {'A': ['light', 'energy'],
#   'B': ['electrical', 'energy'],
#   'C': ['sound', 'energy'],
#   'D': ['heat', 'energy'],
#   'Q': ['Which',
#    'following',
#    'forms',
#    'energy',
#    'released',
#    'absorbed',
#    'chemical',
#    'reactions']},
#  {'A': ['new', 'molecules', 'are', 'formed'],
#   'B': ['the', 'mass', 'of', 'the', 'sample', 'is', 'increased'],
#   'C': ['the', 'arrangement', 'of', 'the', 'molecules', 'changes'],
#   'D': ['energy', 'is', 'absorbed', 'by', 'the', 'molecules'],
#   'Q': ['As', 'sample', 'water', 'turns', 'ice']},
#  {'A': ['sodium', 'Na'],
#   'B': ['lithium', 'Li'],
#   'C': ['sulfur', 'S'],
#   'D': ['carbon', 'C'],
#   'Q': ['Which',
#    'following',
#    'elements',
#    'best',
#    'able',
#    'combine',
#    'hydrogen',
#    'H',
#    'form',
#    'large',
#    'molecules']},
#  {'A': ['Its', 'radius', 'is', '765', 'km'],
#   'B': ['Its', 'density', 'is', 'about', '1', '3', 'kg', 'm3'],
#   'C': ['Its',
#    'period',
#    'of',
#    'rotation',
#    'is',
#    'about',
#    '4',
#    '5',
#    'Earth',
#    'days'],
#   'D': ['Its', 'temperature', 'is', 'between', '174', 'C', 'and', '220', 'C'],
#   'Q': ['Rhea',
#    'moon',
#    'Saturn',
#    'Which',
#    'facts',
#    'Rhea',
#    'best',
#    'indicates',
#    'water',
#    'cycle',
#    'water',
#    'changes',
#    'state']},
#  {'A': ['2'],
#   'B': ['3'],
#   'C': ['4'],
#   'D': ['5'],
#   'Q': ['How', 'many', 'elements', 'compound', 'Mg', 'OH', '2']},
#  {'A': ['Wind'],
#   'B': ['Solar', 'energy'],
#   'C': ['Fossil', 'fuels'],
#   'D': ['Water'],
#   'Q': ['Which', 'resources', 'likely', 'depleted', 'first']},
#  {'A': ['take', 'a', 'break'],
#   'B': ['consume', 'liquids'],
#   'C': ['slow', 'their', 'breathing'],
#   'D': ['stop', 'to', 'eat', 'something'],
#   'Q': ['When',
#    'people',
#    'exercise',
#    'often',
#    'feel',
#    'thirsty',
#    'begin',
#    'sweat',
#    'It',
#    'important',
#    'people',
#    'feel',
#    'thirsty',
#    'exercising',
#    'makes',
#    'realize']},
#  {'A': ['sodium'],
#   'B': ['zinc'],
#   'C': ['fluorine'],
#   'D': ['calcium'],
#   'Q': ['According', 'periodic', 'table', 'following', 'metals', 'except']},
#  {'A': ['prevent',
#    'insects',
#    'from',
#    'taking',
#    'pollen',
#    'to',
#    'other',
#    'flowers'],
#   'B': ['hide',
#    'the',
#    'plant',
#    'from',
#    'predators',
#    'that',
#    'would',
#    'eat',
#    'its',
#    'flowers'],
#   'C': ['protect',
#    'the',
#    'leaves',
#    'from',
#    'injury',
#    'by',
#    'birds',
#    'and',
#    'insects'],
#   'D': ['attract',
#    'insects',
#    'that',
#    'can',
#    'carry',
#    'the',
#    'pollen',
#    'needed',
#    'for',
#    'plant',
#    'reproduction'],
#   'Q': ['The',
#    'petals',
#    'flowers',
#    'often',
#    'brightly',
#    'colored',
#    'These',
#    'petals',
#    'provide',
#    'benefit',
#    'plant']}]
